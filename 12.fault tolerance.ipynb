# %%
from langgraph.graph import StateGraph, START,END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import os
import time
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
#Define state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str
    step3: str

# %%
def step_1(state: CrashState):
    print("Step 1 executed")
    
    return {"step1": "done", "input": state['input']}

# %%
def step_2(state: CrashState):
    print("Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(30) # simulate long-running hang
    return {"step2": "done"}

# %%
def step_3(state: CrashState):
    print("Step 3 executed")
    return {"done":True}

# %%
# build the graph

graph = StateGraph(CrashState)

#add nodes
graph.add_node("step_1",step_1)
graph.add_node("step_2",step_2)
graph.add_node("step_3",step_3)

# add edges
graph.add_edge(START, "step_1")
graph.add_edge("step_1","step_2")
graph.add_edge("step_2","step_3")
graph.add_edge("step_3",END)

checkpointer = InMemorySaver()
workflow = graph.compile(checkpointer = checkpointer)

# %%
try:
    print(" Running graph: please manually interrupt during step 2..")
    workflow.invoke({"input": "start"}, config = {"configurable" : {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("Kernel manually interrupted (crash simulated).")
# Out:
#  Running graph: please manually interrupt during step 2..
# Step 1 executed
# Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# Kernel manually interrupted (crash simulated).

# %%
workflow.get_state({"configurable": {"thread_id": 'thread-1'}})
# Out:
# StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-299c-60e8-8004-5c8cddc1b9d0'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-03T14:48:30.971883+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2996-61c2-8003-5896fce5e5e9'}}, tasks=(PregelTask(id='549699f4-e42f-1fd6-dcec-877276da4826', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
list(workflow.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-299c-60e8-8004-5c8cddc1b9d0'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-03T14:48:30.971883+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2996-61c2-8003-5896fce5e5e9'}}, tasks=(PregelTask(id='549699f4-e42f-1fd6-dcec-877276da4826', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2996-61c2-8003-5896fce5e5e9'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-12-03T14:48:30.969460+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2988-6742-8002-d0f4ab466363'}}, tasks=(PregelTask(id='d78a689d-2a4c-1890-0b65-f65823c5b836', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2988-6742-8002-d0f4ab466363'}}, metadata={'source': 'input', 'step': 2, 'parents': {}}, created_at='2025-12-03T14:48:30.963867+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b075-6227-8001-20925fdf94a7'}}, tasks=(PregelTask(id='6e9267f9-ef6d-ad2b-b1eb-5b21ac178206', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b075-6227-8001-20925fdf94a7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-03T14:38:54.553724+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b06c-6c72-8000-44ed7703ea6d'}}, tasks=(PregelTask(id='abe88432-a1a1-2a65-2982-4c8dd2be638a', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'input': 'start'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b06c-6c72-8000-44ed7703ea6d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-03T14:38:54.550299+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b062-6ca6-bfff-f37240403f3a'}}, tasks=(PregelTask(id='9cf89a83-44d2-529a-c9e8-c382fa8006b9', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b062-6ca6-bfff-f37240403f3a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-03T14:38:54.546212+00:00', parent_config=None, tasks=(PregelTask(id='436887fe-0982-1810-7504-43d635be8c8a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=())]

# %%
final_state = workflow.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n Final state:", final_state)
# Out:
# Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# Step 3 executed
#
#  Final state: {'input': 'start', 'step1': 'done', 'step2': 'done'}

# %%
workflow.get_state({"configurable": {"thread_id": 'thread-1'}})
# Out:
# StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0576-6337-6ffc-8006-bb7c4f2f4af2'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-12-03T14:50:24.386831+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0576-6332-699a-8005-499d8361d03e'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0576-6337-6ffc-8006-bb7c4f2f4af2'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-12-03T14:50:24.386831+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0576-6332-699a-8005-499d8361d03e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=('step_3',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0576-6332-699a-8005-499d8361d03e'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-12-03T14:50:24.384594+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-299c-60e8-8004-5c8cddc1b9d0'}}, tasks=(PregelTask(id='e8ac8592-35f6-db60-991f-797620979983', name='step_3', path=('__pregel_pull', 'step_3'), error=None, interrupts=(), state=None, result={}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-299c-60e8-8004-5c8cddc1b9d0'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-03T14:48:30.971883+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2996-61c2-8003-5896fce5e5e9'}}, tasks=(PregelTask(id='549699f4-e42f-1fd6-dcec-877276da4826', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result={'step2': 'done'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2996-61c2-8003-5896fce5e5e9'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-12-03T14:48:30.969460+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2988-6742-8002-d0f4ab466363'}}, tasks=(PregelTask(id='d78a689d-2a4c-1890-0b65-f65823c5b836', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d0572-2988-6742-8002-d0f4ab466363'}}, metadata={'source': 'input', 'step': 2, 'parents': {}}, created_at='2025-12-03T14:48:30.963867+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b075-6227-8001-20925fdf94a7'}}, tasks=(PregelTask(id='6e9267f9-ef6d-ad2b-b1eb-5b21ac178206', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b075-6227-8001-20925fdf94a7'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-03T14:38:54.553724+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b06c-6c72-8000-44ed7703ea6d'}}, tasks=(PregelTask(id='abe88432-a1a1-2a65-2982-4c8dd2be638a', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'input': 'start'}, next=('step_1',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b06c-6c72-8000-44ed7703ea6d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-03T14:38:54.550299+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b062-6ca6-bfff-f37240403f3a'}}, tasks=(PregelTask(id='9cf89a83-44d2-529a-c9e8-c382fa8006b9', name='step_1', path=('__pregel_pull', 'step_1'), error=None, interrupts=(), state=None, result={'step1': 'done', 'input': 'start'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f0d055c-b062-6ca6-bfff-f37240403f3a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-03T14:38:54.546212+00:00', parent_config=None, tasks=(PregelTask(id='436887fe-0982-1810-7504-43d635be8c8a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'input': 'start'}),), interrupts=())]
