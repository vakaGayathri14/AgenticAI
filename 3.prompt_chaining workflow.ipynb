# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model = os.getenv("GEMINI_MODEL"),
    api_key = os.getenv("Google_API_KEY")

)

# %%
# create a state
class BlogState(TypedDict):
    title: str
    outline: str
    blog_content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch the title
    title = state['title']

    # call the llm and need to generate the outline
    prompt = f" Generate a detailed outline for a blog on the topic - {title}"
    outline = model.invoke(prompt).content
    # needs to update the state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f"write a detailed blog on the title {title} using the following outline \n {outline}"

    blog_content = model.invoke(prompt).content
    state['blog_content'] = blog_content

    return state

# %%
# create object 
graph = StateGraph(BlogState)

# add node
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# add edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

# compile
workflow = graph.compile()
# execute
intial_state ={'title' : 'Rise of AI in Inda'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in Inda', 'outline': '## Blog Post Outline: Rise of AI in India: Opportunities, Challenges, and the Path Forward\n\n**I. Introduction (Hook & Context)**\n\n*   **A. Opening Hook:**\n    *   Start with a compelling statistic or a relatable anecdote showcasing AI\'s impact in India (e.g., AI-powered agriculture increasing yield, AI-driven healthcare reaching rural areas).\n    *   Pose a thought-provoking question about the potential of AI to transform India.\n*   **B. Briefly Define AI:**\n    *   Provide a concise and understandable explanation of Artificial Intelligence (AI).  Avoid overly technical jargon.\n    *   Mention different types of AI (e.g., Machine Learning, Natural Language Processing, Computer Vision) briefly.\n*   **C. Contextualize AI in the Indian Landscape:**\n    *   Highlight India\'s unique position: a large population, a burgeoning tech sector, and pressing societal challenges that AI could address.\n    *   Briefly mention government initiatives and policies supporting AI development.\n*   **D. Thesis Statement:**\n    *   Clearly state the blog post\'s main argument: e.g., "While India stands to gain significantly from the rise of AI, realizing its full potential requires addressing key challenges related to infrastructure, skills gap, ethical considerations, and data privacy."\n\n**II. The Drivers of AI Growth in India (Why Now?)**\n\n*   **A. Technological Advancements:**\n    *   Affordable computing power (cloud computing).\n    *   Availability of large datasets (data is the fuel for AI).\n    *   Progress in AI algorithms and frameworks.\n*   **B. Government Support and Initiatives:**\n    *   National AI Strategy: Briefly describe its goals and key focus areas.\n    *   Investment in AI research and development.\n    *   Promotion of AI adoption in various sectors.\n*   **C. Thriving Tech Ecosystem:**\n    *   Presence of numerous startups and established tech companies working on AI.\n    *   Availability of venture capital funding for AI ventures.\n    *   Strong base of IT professionals and engineers.\n*   **D. Addressing Societal Challenges:**\n    *   AI solutions for agriculture (precision farming, crop monitoring).\n    *   AI-powered healthcare (diagnosis, telemedicine, drug discovery).\n    *   AI for education (personalized learning, automated grading).\n    *   AI for infrastructure (smart cities, traffic management).\n\n**III. Key Sectors Where AI is Making a Difference**\n\n*   **A. Agriculture:**\n    *   Examples: AI-powered crop yield prediction, disease detection, automated irrigation.\n    *   Impact: Increased productivity, reduced waste, improved farmer income.\n*   **B. Healthcare:**\n    *   Examples: AI-assisted diagnosis, robotic surgery, personalized medicine, drug discovery.\n    *   Impact: Improved patient outcomes, reduced healthcare costs, increased access to healthcare.\n*   **C. Finance:**\n    *   Examples: Fraud detection, risk assessment, algorithmic trading, customer service chatbots.\n    *   Impact: Enhanced security, improved efficiency, personalized financial services.\n*   **D. Retail and E-commerce:**\n    *   Examples: Personalized recommendations, chatbot customer service, supply chain optimization, fraud detection.\n    *   Impact: Increased sales, improved customer satisfaction, streamlined operations.\n*   **E. Manufacturing:**\n    *   Examples: Predictive maintenance, quality control, robotic automation, supply chain optimization.\n    *   Impact: Increased efficiency, reduced downtime, improved product quality.\n\n**IV. Challenges Hindering AI Adoption in India**\n\n*   **A. Infrastructure Limitations:**\n    *   Limited internet connectivity, especially in rural areas.\n    *   Lack of adequate computing infrastructure.\n    *   Challenges in accessing and managing large datasets.\n*   **B. Skills Gap and Talent Shortage:**\n    *   Shortage of skilled AI professionals (data scientists, machine learning engineers).\n    *   ...

# %%
print(final_state['outline'])
# Out:
# ## Blog Post Outline: Rise of AI in India: Opportunities, Challenges, and the Path Forward
#
# **I. Introduction (Hook & Context)**
#
# *   **A. Opening Hook:**
#     *   Start with a compelling statistic or a relatable anecdote showcasing AI's impact in India (e.g., AI-powered agriculture increasing yield, AI-driven healthcare reaching rural areas).
#     *   Pose a thought-provoking question about the potential of AI to transform India.
# *   **B. Briefly Define AI:**
#     *   Provide a concise and understandable explanation of Artificial Intelligence (AI).  Avoid overly technical jargon.
#     *   Mention different types of AI (e.g., Machine Learning, Natural Language Processing, Computer Vision) briefly.
# *   **C. Contextualize AI in the Indian Landscape:**
#     *   Highlight India's unique position: a large population, a burgeoning tech sector, and pressing societal challenges that AI could address.
#     *   Briefly mention government initiatives and policies supporting AI development.
# *   **D. Thesis Statement:**
#     *   Clearly state the blog post's main argument: e.g., "While India stands to gain significantly from the rise of AI, realizing its full potential requires addressing key challenges related to infrastructure, skills gap, ethical considerations, and data privacy."
#
# **II. The Drivers of AI Growth in India (Why Now?)**
#
# *   **A. Technological Advancements:**
#     *   Affordable computing power (cloud computing).
#     *   Availability of large datasets (data is the fuel for AI).
#     *   Progress in AI algorithms and frameworks.
# *   **B. Government Support and Initiatives:**
#     *   National AI Strategy: Briefly describe its goals and key focus areas.
#     *   Investment in AI research and development.
#     *   Promotion of AI adoption in various sectors.
# *   **C. Thriving Tech Ecosystem:**
#     *   Presence of numerous startups and established tech companies working on AI.
#     *   Availability of venture capital funding for AI ventures.
#     *   Strong base of IT professionals and engineers.
# *   **D. Addressing Societal Challenges:**
#     *   AI solutions for agriculture (precision farming, crop monitoring).
#     *   AI-powered healthcare (diagnosis, telemedicine, drug discovery).
#     *   AI for education (personalized learning, automated grading).
#     *   AI for infrastructure (smart cities, traffic management).
#
# **III. Key Sectors Where AI is Making a Difference**
#
# *   **A. Agriculture:**
#     *   Examples: AI-powered crop yield prediction, disease detection, automated irrigation.
#     *   Impact: Increased productivity, reduced waste, improved farmer income.
# *   **B. Healthcare:**
#     *   Examples: AI-assisted diagnosis, robotic surgery, personalized medicine, drug discovery.
#     *   Impact: Improved patient outcomes, reduced healthcare costs, increased access to healthcare.
# *   **C. Finance:**
#     *   Examples: Fraud detection, risk assessment, algorithmic trading, customer service chatbots.
#     *   Impact: Enhanced security, improved efficiency, personalized financial services.
# *   **D. Retail and E-commerce:**
#     *   Examples: Personalized recommendations, chatbot customer service, supply chain optimization, fraud detection.
#     *   Impact: Increased sales, improved customer satisfaction, streamlined operations.
# *   **E. Manufacturing:**
#     *   Examples: Predictive maintenance, quality control, robotic automation, supply chain optimization.
#     *   Impact: Increased efficiency, reduced downtime, improved product quality.
#
# **IV. Challenges Hindering AI Adoption in India**
#
# *   **A. Infrastructure Limitations:**
#     *   Limited internet connectivity, especially in rural areas.
#     *   Lack of adequate computing infrastructure.
#     *   Challenges in accessing and managing large datasets.
# *   **B. Skills Gap and Talent Shortage:**
#     *   Shortage of skilled AI professionals (data scientists, machine learning engineers).
#     *   Need for specialized training and education programs.
#     *   Importance of reskilling and upskilling the existing workforce.
# *   **C. Data Privacy and Security Concerns:**
#     *   Need for robust data protection laws and regulations.
#     *   Ensuring ethical and responsible use of data.
#     *   Addressing concerns about data breaches and misuse.
# *   **D. Ethical Considerations and Bias:**
#     *   Potential for AI algorithms to perpetuate existing biases.
#     *   Need for fairness, transparency, and accountability in AI systems.
#     *   Addressing ethical dilemmas related to AI decision-making.
# *   **E. Lack of Awareness and Understanding:**
#     *   Limited awareness among businesses and individuals about the potential benefits of AI.
#     *   Need for education and outreach programs to promote AI adoption.
#
# **V. The Path Forward: Recommendations and Solutions**
#
# *   **A. Investing in Infrastructure Development:**
#     *   Expanding internet connectivity, especially in rural areas.
#     *   Building robust computing infrastructure and data centers.
#     *   Promoting open data initiatives and data sharing.
# *   **B. Bridging the Skills Gap:**
#     *   Investing in AI education and training programs.
#     *   Collaborating with universities and industry to develop relevant curricula.
#     *   Offering scholarships and fellowships to attract talent to the field.
# *   **C. Strengthening Data Privacy and Security:**
#     *   Enacting comprehensive data protection laws.
#     *   Implementing robust security measures to protect data.
#     *   Promoting data literacy and awareness among citizens.
# *   **D. Establishing Ethical Guidelines and Frameworks:**
#     *   Developing ethical principles for AI development and deployment.
#     *   Establishing regulatory frameworks to ensure fairness, transparency, and accountability.
#     *   Promoting public dialogue and engagement on ethical issues related to AI.
# *   **E. Fostering Collaboration and Innovation:**
#     *   Encouraging collaboration between academia, industry, and government.
#     *   Providing funding and support for AI research and development.
#     *   Creating a conducive environment for AI startups and innovation.
#
# **VI. Conclusion (Recap & Future Outlook)**
#
# *   **A. Recap of Key Points:**
#     *   Summarize the key drivers of AI growth in India.
#     *   Reiterate the challenges that need to be addressed.
#     *   Emphasize the importance of taking a proactive and strategic approach.
# *   **B. Future Outlook:**
#     *   Paint a picture of the potential future of AI in India.
#     *   Highlight the opportunities for economic growth, social progress, and global leadership.
#     *   Emphasize the need for continued investment, collaboration, and innovation.
# *   **C. Call to Action:**
#     *   Encourage readers to learn more about AI and its potential.
#     *   Suggest ways they can contribute to the responsible and beneficial development of AI in India.
#     *   Leave the reader with a sense of optimism and excitement about the future of AI in India.
#
# **VII. Optional Elements:**
#
# *   **Infographics:** Visual representations of data and statistics.
# *   **Case Studies:** Real-world examples of AI applications in India.
# *   **Expert Quotes:** Insights from industry leaders, academics, and policymakers.
# *   **Interactive Elements:** Polls, quizzes, or comment sections to engage readers.
# *   **References:** Links to relevant articles, reports, and resources.
#
# This outline provides a comprehensive framework for your blog post. Remember to tailor the content to your specific target audience and writing style. Good luck!

# %%
print(final_state['blog_content'])
# Out:
# ## Rise of AI in India: Opportunities, Challenges, and the Path Forward
#
# **I. Introduction (Hook & Context)**
#
# **A. Opening Hook:**
#
# Imagine a farmer in rural Maharashtra, using a smartphone app to analyze soil conditions and predict optimal planting times, leading to a 30% increase in crop yield. This isn't science fiction; it's the reality being shaped by Artificial Intelligence (AI) in India.  Could AI be the key to unlocking India's immense potential and solving some of its most pressing challenges?
#
# **B. Briefly Define AI:**
#
# Artificial Intelligence (AI) is the ability of a computer or a machine to mimic human cognitive functions such as learning, problem-solving, and decision-making. It's not about robots taking over the world (at least, not yet!), but about creating intelligent systems that can automate tasks, analyze data, and provide insights.  Different types of AI include Machine Learning (where systems learn from data), Natural Language Processing (enabling computers to understand and process human language), and Computer Vision (allowing computers to "see" and interpret images).
#
# **C. Contextualize AI in the Indian Landscape:**
#
# India stands at a unique crossroads. With a vast and diverse population, a rapidly growing tech sector, and persistent societal issues like poverty, healthcare access, and agricultural productivity, the potential for AI to drive transformative change is immense. The Indian government recognizes this potential and has launched several initiatives to foster AI development and adoption, positioning India as a global leader in this transformative technology.
#
# **D. Thesis Statement:**
#
# While India stands to gain significantly from the rise of AI, realizing its full potential requires addressing key challenges related to infrastructure limitations, a critical skills gap, stringent ethical considerations, and the imperative of ensuring data privacy.
#
# **II. The Drivers of AI Growth in India (Why Now?)**
#
# **A. Technological Advancements:**
#
# Several technological factors are fueling the AI boom in India.  The affordability and scalability of cloud computing provide access to the immense processing power needed for AI training.  The increasing availability of large datasets, often generated through digital platforms and government initiatives, provides the "fuel" that AI algorithms need to learn and improve.  Finally, significant progress in AI algorithms and open-source frameworks has made AI development more accessible than ever before.
#
# **B. Government Support and Initiatives:**
#
# The Indian government is actively promoting AI through various initiatives. The National AI Strategy aims to position India as a global hub for AI innovation and development. This strategy outlines key focus areas like healthcare, agriculture, education, and smart cities.  The government is also investing in AI research and development through grants, funding programs, and partnerships with academic institutions.  Furthermore, policies are being implemented to encourage the adoption of AI across various sectors.
#
# **C. Thriving Tech Ecosystem:**
#
# India boasts a thriving tech ecosystem that provides a fertile ground for AI innovation. Numerous startups and established tech companies are actively developing and deploying AI solutions.  Venture capital funding is increasingly flowing into AI ventures, enabling them to scale and expand their reach. The country also has a strong base of IT professionals and engineers, many of whom are eager to learn and contribute to the AI revolution.
#
# **D. Addressing Societal Challenges:**
#
# AI offers powerful solutions to address some of India's most pressing societal challenges. In agriculture, AI can be used for precision farming, crop monitoring, and disease detection, leading to increased yields and improved farmer livelihoods. In healthcare, AI can power diagnostic tools, telemedicine platforms, and drug discovery efforts, improving patient outcomes and increasing access to healthcare in remote areas. AI can also enhance education through personalized learning and automated grading, and improve infrastructure through smart cities initiatives and traffic management systems.
#
# **III. Key Sectors Where AI is Making a Difference**
#
# **A. Agriculture:**
#
# AI is transforming Indian agriculture. AI-powered crop yield prediction models help farmers make informed decisions about planting and harvesting.  AI-based disease detection systems can identify and treat crop diseases early, minimizing losses. Automated irrigation systems optimize water usage, conserving precious resources.  The impact? Increased productivity, reduced waste, and improved income for farmers who are often the backbone of the Indian economy.
#
# **B. Healthcare:**
#
# AI is revolutionizing healthcare in India. AI-assisted diagnostic tools can help doctors detect diseases earlier and more accurately. Robotic surgery is becoming increasingly common, enabling more precise and minimally invasive procedures.  Personalized medicine, powered by AI, tailors treatment plans to individual patients' genetic profiles.  AI is also accelerating drug discovery, leading to the development of new and more effective treatments. This translates to improved patient outcomes, reduced healthcare costs, and increased access to quality healthcare, especially in underserved communities.
#
# **C. Finance:**
#
# The financial sector in India is embracing AI to enhance security, improve efficiency, and personalize services. AI-powered fraud detection systems can identify and prevent fraudulent transactions in real-time.  Risk assessment models use AI to evaluate creditworthiness and manage risk more effectively. Algorithmic trading systems automate trading decisions, improving efficiency and profitability.  Customer service chatbots provide instant support and resolve customer queries quickly and efficiently.
#
# **D. Retail and E-commerce:**
#
# AI is transforming the retail and e-commerce landscape in India. Personalized recommendations, powered by AI algorithms, suggest products that are most relevant to individual customers.  Chatbot customer service provides instant support and enhances the customer experience. AI is also used to optimize supply chains, ensuring that products are delivered to customers quickly and efficiently. Fraud detection systems protect businesses and customers from fraudulent activities.
#
# **E. Manufacturing:**
#
# AI is driving efficiency and innovation in the Indian manufacturing sector. Predictive maintenance systems use AI to predict equipment failures, allowing manufacturers to schedule maintenance proactively and minimize downtime.  Quality control systems use AI to detect defects in products, ensuring high quality standards. Robotic automation streamlines manufacturing processes, increasing efficiency and reducing costs.  AI also optimizes supply chains, ensuring that materials are available when and where they are needed.
#
# **IV. Challenges Hindering AI Adoption in India**
#
# **A. Infrastructure Limitations:**
#
# Despite progress, India still faces significant infrastructure limitations that hinder AI adoption.  Limited internet connectivity, particularly in rural areas, restricts access to cloud computing and data resources.  A lack of adequate computing infrastructure, including high-performance servers and data centers, limits the ability to train and deploy AI models.  Challenges in accessing and managing large datasets, due to data silos and a lack of data standards, impede AI development.
#
# **B. Skills Gap and Talent Shortage:**
#
# A critical skills gap and talent shortage are major obstacles to AI adoption in India.  There is a shortage of skilled AI professionals, including data scientists, machine learning engineers, and AI researchers.  Specialized training and education programs are needed to equip individuals with the skills required to develop and deploy AI solutions.  Reskilling and upskilling the existing workforce is essential to ensure that employees can adapt to the changing demands of the AI-driven economy.
#
# **C. Data Privacy and Security Concerns:**
#
# Data privacy and security are paramount concerns in the age of AI.  Robust data protection laws and regulations are needed to safeguard personal data and prevent misuse.  Ensuring ethical and responsible use of data is crucial to maintain public trust.  Addressing concerns about data breaches and misuse is essential to protect individuals and organizations from harm.
#
# **D. Ethical Considerations and Bias:**
#
# AI algorithms can perpetuate existing biases if they are trained on biased data.  Fairness, transparency, and accountability are essential principles for AI systems.  Addressing ethical dilemmas related to AI decision-making is crucial to ensure that AI is used responsibly and ethically.  This requires careful consideration of the potential impact of AI on different groups and individuals.
#
# **E. Lack of Awareness and Understanding:**
#
# Limited awareness among businesses and individuals about the potential benefits of AI is a barrier to adoption.  Education and outreach programs are needed to promote AI adoption and dispel misconceptions about the technology.  Demonstrating the value of AI through real-world examples and case studies can help to increase awareness and understanding.
#
# **V. The Path Forward: Recommendations and Solutions**
#
# **A. Investing in Infrastructure Development:**
#
# To overcome infrastructure limitations, India needs to expand internet connectivity, particularly in rural areas, through initiatives like BharatNet.  Building robust computing infrastructure and data centers is crucial for supporting AI development and deployment.  Promoting open data initiatives and data sharing can unlock the potential of data for AI innovation.
#
# **B. Bridging the Skills Gap:**
#
# To address the skills gap, India needs to invest in AI education and training programs at all levels.  Collaborating with universities and industry to develop relevant curricula is essential to ensure that students are equipped with the skills that employers need.  Offering scholarships and fellowships to attract talent to the field can help to build a pipeline of skilled AI professionals.
#
# **C. Strengthening Data Privacy and Security:**
#
# To strengthen data privacy and security, India needs to enact comprehensive data protection laws that are aligned with international standards.  Implementing robust security measures to protect data from breaches and misuse is crucial.  Promoting data literacy and awareness among citizens can empower them to protect their own data.
#
# **D. Establishing Ethical Guidelines and Frameworks:**
#
# To ensure the ethical use of AI, India needs to develop ethical principles for AI development and deployment.  Establishing regulatory frameworks to ensure fairness, transparency, and accountability is essential.  Promoting public dialogue and engagement on ethical issues related to AI can help to build consensus around responsible AI development.
#
# **E. Fostering Collaboration and Innovation:**
#
# To foster collaboration and innovation, India needs to encourage collaboration between academia, industry, and government.  Providing funding and support for AI research and development is crucial for driving innovation.  Creating a conducive environment for AI startups and innovation can help to accelerate the development and deployment of AI solutions.
#
# **VI. Conclusion (Recap & Future Outlook)**
#
# **A. Recap of Key Points:**
#
# AI is poised to transform India across various sectors, driven by technological advancements, government support, and a thriving tech ecosystem.  However, realizing the full potential of AI requires addressing challenges related to infrastructure, skills, data privacy, ethics, and awareness.  Taking a proactive and strategic approach is essential to ensure that AI benefits all of Indian society.
#
# **B. Future Outlook:**
#
# The future of AI in India is bright. AI has the potential to drive economic growth, improve social progress, and position India as a global leader in AI innovation.  Continued investment, collaboration, and innovation are essential to realize this potential.  Imagine a future where AI-powered healthcare is accessible to everyone, AI-driven agriculture ensures food security, and AI-enabled education empowers all citizens to reach their full potential.
#
# **C. Call to Action:**
#
# Learn more about AI and its potential to transform India.  Support initiatives that promote responsible and beneficial AI development.  Engage in public dialogue about the ethical implications of AI.  Contribute to the development of AI solutions that address India's unique challenges.  The future of AI in India is in our hands. Let's work together to ensure that it is a future that benefits all of us.
#
# **VII. Optional Elements:**
#
# *   **Infographics:**  (Example: A chart showing the growth of AI startups in India over the past 5 years)
# *   **Case Studies:** (Example: A detailed look at how an AI-powered chatbot is improving customer service for a major Indian bank)
# *   **Expert Quotes:** (Example: "AI has the potential to leapfrog India's development and address some of our most pressing challenges," - Dr. [Fictional Name], AI Researcher)
# *   **Interactive Elements:** (Example: A poll asking readers which sector they think will be most impacted by AI in India)
# *   **References:** (Links to the National AI Strategy, relevant research papers, and industry reports)
